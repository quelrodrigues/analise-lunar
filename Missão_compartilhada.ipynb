# %% [markdown]
# <a href="https://colab.research.google.com/github/quelrodrigues/analise-lunar/blob/Luana-C/Miss%C3%A3o_compartilhada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/quelrodrigues/analise-lunar.git
# Out:
# fatal: destination path 'analise-lunar' already exists and is not an empty directory.

# %%
# !pip install numpy matplotlib keras

# %%
import pandas as pd

# %%
#Quero que o pandas leia o dado
df_lua = pd.read_csv('/content/analise-lunar/Moonlanding.csv')
display(df_lua)
# Out:
#                    Mission       Spacecraft Launch Date      Carrier Rocket  \
# 0       Pioneer 0 (Able I)        Pioneer 0   17-Aug-58   Thor DM-18 Able I
# 1            Luna E-1 No.1    Luna E-1 No.1   23-Sep-58                Luna
# 2      Pioneer 1 (Able II)        Pioneer 1   11-Oct-58   Thor DM-18 Able I
# 3            Luna E-1 No.2    Luna E-1 No.2   11-Oct-58                Luna
# 4     Pioneer 2 (Able III)        Pioneer 2   08-Nov-58   Thor DM-18 Able I
# ..                     ...              ...         ...                 ...
# 161  Peregrine Mission One        Peregrine   08-Jan-24  Vulcan Centaur VC2
# 162  Peregrine Mission One      Colmena ? 5   08-Jan-24  Vulcan Centaur VC2
# 163  Peregrine Mission One             Iris   08-Jan-24  Vulcan Centaur VC2
# 164                   IM-1  Nova-C Odysseus   14-Feb-24         Falcon 9 B5
# 165                   IM-1         EagleCam   14-Feb-24         Falcon 9 B5
#
# ...

# %%
#solução do desafio Aluno1
#tarefa1
display(df_lua['Mission Type'].value_counts())

#tarefa2
display(df_lua['Operator'].value_counts())
# Out:
# Mission Type
# Orbiter                                 59
# Lander                                  40
# Flyby                                   31
# Impactor                                15
# Rover                                    6
# Lander,Sample Return                     2
# Orbiter,Lander,Rover                     2
# Flybys                                   2
# Crewed orbiter                           1
# Flyby / Impactor (post mission)          1
# Relay Satellite                          1
# Launch Vehicle                           1
# Sample Return                            1
# Lander                                   1
# Hopper                                   1
# Rovers                                   1
# Deployable camera (semi hard lander)     1
# Name: count, dtype: int64
# Operator
# United States NASA                   61
# Soviet Union Lavochkin               39
# Soviet Union OKB-1                   15
# China CNSA                           15
# ...

# %%
#aluno2
#tarefa1
display(df_lua['Carrier Rocket'].value_counts())
#Tarefa2
display(df_lua['Spacecraft'].value_counts())
# Out:
# Carrier Rocket
# Proton-K/D                  24
# Molniya-M                   12
# SLS Block 1                 11
# Saturn V                    10
# Luna                         9
# Atlas LV-3 Agena-B           6
# Atlas SLV-3 Agena-D          5
# Molniya-L                    5
# Long March 3C                4
# Atlas LV-3C Centaur-D        4
# Falcon 9 Block 5             4
# Long March 3B                4
# Long March 5                 4
# Thor DM-18 Able I            3
#   H-IIA                      3
# Vulcan Centaur VC2           3
# H-IIA 2022                   3
# Atlas-D Able                 3
# Atlas SLV-3C Centaur-D       3
# Molniya                      3
# Long March 4C                3
# Juno II                      2
# Delta E1                     2
# Falcon 9                     2
# Delta II 7925                2
# PSLV-XL C11                  2
# Atlas V 401                  2
# Falcon 9 B5                  2
# Delta 1913                   1
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/quelrodrigues/analise-lunar/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar dados dos github

# %%
#importar dados lunares
# !git clone https://github.com/quelrodrigues/analise-missoes-lunares.git
# Out:
# Cloning into 'analise-missoes-lunares'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# Receiving objects: 100% (6/6), 10.23 KiB | 10.23 MiB/s, done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)

# %% [markdown]
# # Bibliotecas

# %%
# !pip install numpy matplotlib keras

# %%
import pandas as pd
#estamos colocando no código todos
#os conhecimento de "análise de dados"

# %% [markdown]
# # Código

# %%
#quero que o pandas leia o arquivo
df_lua = pd.read_csv("/content/analise-missoes-lunares/Moonlanding.csv")

display(df_lua)
# Out:
#                    Mission       Spacecraft Launch Date      Carrier Rocket  \
# 0       Pioneer 0 (Able I)        Pioneer 0   17-Aug-58   Thor DM-18 Able I
# 1            Luna E-1 No.1    Luna E-1 No.1   23-Sep-58                Luna
# 2      Pioneer 1 (Able II)        Pioneer 1   11-Oct-58   Thor DM-18 Able I
# 3            Luna E-1 No.2    Luna E-1 No.2   11-Oct-58                Luna
# 4     Pioneer 2 (Able III)        Pioneer 2   08-Nov-58   Thor DM-18 Able I
# ..                     ...              ...         ...                 ...
# 161  Peregrine Mission One        Peregrine   08-Jan-24  Vulcan Centaur VC2
# 162  Peregrine Mission One      Colmena ? 5   08-Jan-24  Vulcan Centaur VC2
# 163  Peregrine Mission One             Iris   08-Jan-24  Vulcan Centaur VC2
# 164                   IM-1  Nova-C Odysseus   14-Feb-24         Falcon 9 B5
# 165                   IM-1         EagleCam   14-Feb-24         Falcon 9 B5
#
# ...

# %%
#mostra as informações gerais de uma base de dados
df_lua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Mission                 166 non-null    object
#  1   Spacecraft              166 non-null    object
#  2   Launch Date             166 non-null    object
#  3   Carrier Rocket          166 non-null    object
#  4   Operator                166 non-null    object
#  5   Mission Type            166 non-null    object
#  6   Outcome                 166 non-null    object
#  7   Additional Information  165 non-null    object
# dtypes: object(8)
# memory usage: 10.5+ KB

# %%
#o comando describe mostra dados de estatistica básica sobre a base de dados
df_lua.describe()
# Out:
#           Mission Spacecraft Launch Date Carrier Rocket            Operator  \
# count         166        166         166            166                 166
# unique        150        166         129             54                  29
# top     Chang'e 5  Pioneer 0   16-Nov-22     Proton-K/D  United States NASA
# freq            4          1          11             24                  61
#
#        Mission Type     Outcome  \
# count           166         166
# unique           17          10
# top         Orbiter  Successful
# freq             59          78
#
#                                    Additional Information
# count                                                 165
# unique                                                154
# top     Returned lunar samples on 16 December 2020. Or...
# freq                                                    4

# %%
#foi solicitado para os analistas as seguintes informações
# 1- quantas missões por operador?
display(df_lua['Operator'].value_counts())

# 2 - quantas missões por "mission type"
display(df_lua['Mission Type'].value_counts())
# Out:
# Operator
# United States NASA                   61
# Soviet Union Lavochkin               39
# Soviet Union OKB-1                   15
# China CNSA                           15
# Japan JAXA                            5
# India ISRO                            4
# Japan ISAS                            3
# European Union ESA                    2
# Tomy / JAXA / Doshisha University     2
# United States Hughes                  1
# United States USAF/NASA               1
# Japan United States ISAS/NASA         1
# United States USAF                    1
# Luxembourg LuxSpace                   1
# Israel SpaceIL                        1
# Italy ASI                             1
# South Korea KARI                      1
# United States Fluid & Reason          1
# Japan ispace                          1
# Japan Tomy/JAXA/Dodai                 1
# United States Lockheed Martin         1
# UAE UAESA/MBRSC                       1
# Russia Roscosmos                      1
# ...

# %%
# porcentagem de sucesso das missões
#o comando normalize msotra a "porcentagem" que o dado aparece na base
display(df_lua['Outcome'].value_counts(normalize=True)*100)
# Out:
# Outcome
# Successful              46.987952
# Launch failure          18.674699
# Spacecraft failure      17.469880
# Operational              8.433735
# Partial failure          3.614458
# Operational              1.807229
# Precluded                1.204819
# En route                 0.602410
# Partial success          0.602410
# Awaiting Deployment      0.602410
# Name: proportion, dtype: float64
